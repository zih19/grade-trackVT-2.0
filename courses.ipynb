# %%
import os
import pandas as pd

# %%
directory_path_CS = "./course_data/CS"

CS_CSV_files = os.listdir(directory_path_CS)
for file in CS_CSV_files:
    CS_file_path = os.path.join(directory_path_CS, file)
    df = pd.read_csv(CS_file_path)
    print("The course number of the CS course is: ", df['Course No.'].unique())
    print("\n")
    print("The course title is: ", df['Course Title'].unique())
    print("\n")
    print("The average gpa for this course is: ", round(df['GPA'].mean(), 2))
    print("\n")
    print("The total number of people to be enrolled is: ",  df['Graded Enrollment'].sum())
    print("\n")
    print("The total number of people to be withdrawn is: ", df['Withdraws'].sum())
    print("\n")
    print("The credit(s) for this course is: ", df['Credits'].unique())
    print("\n")
    print("The name(s) of the instructors are:  ", df['Instructor'].unique())
    print("\n")
# Out:
# The course number of the CS course is:  [1044]
#
#
# The course title is:  ['Intro Prog in C']
#
#
# The average gpa for this course is:  3.19
#
#
# The total number of people to be enrolled is:  691
#
#
# The total number of people to be withdrawn is:  23
#
#
# The credit(s) for this course is:  [3]
#
#
# The name(s) of the instructors are:   ['Stevens']
#
#
# The course number of the CS course is:  [1054]
#
#
# The course title is:  ['Intro to Programming in Java']
#
#
# The average gpa for this course is:  2.87
#
#
# The total number of people to be enrolled is:  1032
#
#
# The total number of people to be withdrawn is:  80
#
#
# The credit(s) for this course is:  [3]
#
#
# The name(s) of the instructors are:   ['Barnette' 'Hillman' 'Gusukuma' 'Farghally' 'Lewis']
#
#
# The course number of the CS course is:  [1064]
#
#
# The course title is:  ['Intro to Programming in Python']
#
#
# The average gpa for this course is:  3.58
#
#
# ...
